# %% [markdown]
# # Analysing Premier League seasons

# %%
# Importing libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
All_season = pd.read_csv("Datasets/All_season")
Stad_capacity = pd.read_csv("Datasets/Seasons/Stadium_details")

# %% [markdown]
# ### Lets find the answers for these questions from the data.
# 1. Trend over time.
#    - How have total points changed over the years?
#    - Have goals per season increased or decreased.
#    - Which teams have been the most consistent? (Top 4 finishes, relegation battles).
#    - Has the league got competitive over time or not.
# 2. Performance analysis
#    - Which teams have the best points per match over years?
#    - Are there patterns in how promoted teams perform in their first season?
#    - Which teams rely the most on their top scorer for goals?
# 3. Correlation Analysis.
#    - Do teams with higher average attendance perform better?
#    - Is there a strong relationship between goal difference and final leagure position?
#    - How important is having a top scorer with 20+ goals for league success?
# 4. Relegation & Promotion trends.
#    - How often do newly promoted teams get relegated?
#    - Which teams have bounced back quickly after relegation.
# 5. Forming some actionable thumb rules based on the trends (previous seasons) for avoiding relegation, qualify for top 5 positions & win the league.
# 6. How to form a team based on the thumb rules.

# %% [markdown]
# - Seasons Analysis
# - Attendance trends of season
# - Points trends of Champion teams
# - Points, Goal difference various traits of relegated teams.
# - Performance of teams promoted but not relegated.
# - Points to Rank trends to see competition among teams

# %%
All_season
# Out:
#      Rk            Squad  MP   W   D   L  GF   GA  GD  Pts  Pts/MP  \
# 0     1   Manchester Utd  42  24  12   6  67   31  36   84    2.00
# 1     2      Aston Villa  42  21  11  10  57   40  17   74    1.76
# 2     3     Norwich City  42  21   9  12  61   65  -4   72    1.71
# 3     4        Blackburn  42  20  11  11  68   46  22   71    1.69
# 4     5              QPR  42  17  12  13  63   55   8   63    1.50
# ..   ..              ...  ..  ..  ..  ..  ..  ...  ..  ...     ...
# 641  16        Brentford  38  10   9  19  56   65  -9   39    1.03
# 642  17  Nott'ham Forest  38   9   9  20  49   67 -18   32    0.84
# 643  18       Luton Town  38   6   8  24  52   85 -33   26    0.68
# 644  19          Burnley  38   5   9  24  41   78 -37   24    0.63
# 645  20    Sheffield Utd  38   3   7  28  35  104 -69   16    0.42
#
#      Attendance                Top Team Scorer        Goalkeeper  \
# 0         35132                    Mark Hughes  Peter Schmeichel
# ...

# %%
Stad_capacity.head()
# Out:
#                                      Stadium  Image           Club  \
# 0                                    Anfield    NaN      Liverpool
# 1   Arsenal Stadium (also known as Highbury)    NaN        Arsenal
# 2                              Ayresome Park    NaN  Middlesbrough
# 3                            Baseball Ground    NaN   Derby County
# 4  bet365 Stadium Formerly Britannia Stadium    NaN     Stoke City
#
#          Location Opened  Closed Capacity  Pitch length (m)  Pitch width (m)  \
# 0       Liverpool   1884     NaN    61276             101.0             68.0
# 1          London   1913  2006.0  38,419†               NaN              NaN
# 2   Middlesbrough   1903  1995.0  26,667†               NaN              NaN
# 3           Derby   1892  2004.0  18,300†               NaN              NaN
# 4  Stoke-on-Trent   1997     NaN    30089               NaN              NaN
#
#                                        Coordinates      Ref.
# ...

# %%
Stad_capacity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 1 to 59
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Stadium           61 non-null     object
#  1   Club              61 non-null     object
#  2   Location          61 non-null     object
#  3   Opened            61 non-null     object
#  4   Closed            61 non-null     object
#  5   Capacity          61 non-null     object
#  6   Pitch length (m)  61 non-null     object
#  7   Pitch width (m)   61 non-null     object
#  8   Coordinates       61 non-null     object
# dtypes: object(9)
# memory usage: 4.8+ KB

# %%
del Stad_capacity['Image']
del Stad_capacity['Ref.']

# %%
Stad_capacity.sort_values(by='Club',inplace=True)
Stad_capacity
# Out:
#                                      Stadium                     Club  \
# 1   Arsenal Stadium (also known as Highbury)                  Arsenal
# 21                          Emirates Stadium                  Arsenal
# 58                                Villa Park              Aston Villa
# 39                                   Oakwell                 Barnsley
# 45                               St Andrew's          Birmingham City
# ..                                       ...                      ...
# 34   London Stadium Formerly Olympic Stadium          West Ham United
# 6   Boleyn Ground (also known as Upton Park)          West Ham United
# 19           DW Stadium Formerly JJB Stadium           Wigan Athletic
# 38                          Molineux Stadium  Wolverhampton Wanderers
# 59                           Wembley Stadium                  —[nb 1]
#
#          Location    Opened           Closed Capacity Pitch length (m)  \
# ...

# %%
Stad_capacity['Closed'] = Stad_capacity['Closed'].fillna('Current Stadium')
Stad_capacity['Pitch length (m)'] = Stad_capacity['Pitch length (m)'].fillna('Not available')
Stad_capacity['Pitch width (m)'] = Stad_capacity['Pitch width (m)'].fillna('Not available')

# %% [markdown]
# Arsenal, Bolton Wanderers, Derby County, Leicester City, Manchester City, Middlesbrough, Southampton,Tottenham Hotspur, West Ham United

# %% [markdown]
# Arsenal 2005-2006 - 38419 and after 2006-2007  - 60704, Leicester City - 22,000 - 2003-2004 - 32259, Man City - 35,150 - 2003-2004 - 52900, Middlesbrough - 26,667 - 1996-1997 - 33746, Southampton - 15,200 -2001-2002 - 32384, Tottenham Hotspur - 36,284 - 2017-2018 - 62850, West Ham United - 35,345 - 2016-2017	- 62500

# %%
All_season['Squad'] = All_season['Squad'].apply(lambda x : x.strip())

# %%
All_season['Top_scorer_goal_contribution_%'] = round(All_season['Goals scored by top team scorer']/All_season['GF']*100,2)

# %%
All_season['Notes'] = All_season.Notes.fillna('Stayed_in_PL')

# %%
All_season['Goals_per_Match'] = round(All_season['GF']/All_season['MP'],2)
All_season['Goals_Conceded_per_Game'] = round(All_season['GA'] / All_season['MP'],2)
All_season['Top_Scorer_Goals_per_Game'] = round(All_season['Goals scored by top team scorer'] / All_season['MP'],2)
All_season['Win_%'] = round(All_season['W'] / All_season['MP']*100,2)
All_season['Draw_%'] = round(All_season['D'] / All_season['MP']*100,2)
All_season['Loss_%'] = round(All_season['L'] / All_season['MP']*100,2)

# %%
All_season.to_csv(f'Datasets/Seasons/All_season',index=False)

# %% [markdown]
# ##  Seasons Analysis

# %% [markdown]
# Trend over time.
#    - How have total points changed over the years?
#    - Which teams have been the most consistent? (Top 4 finishes, relegation battles).
#    - Have goals per season increased or decreased.
#    - Has the league got competitive over time or not.

# %%
All_season.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'Attendance', 'Top Team Scorer', 'Goalkeeper', 'Notes', 'Season',
#        'Goals scored by top team scorer', 'years_in_PL_after_promotion',
#        'Promoted', 'Top_scorer_goal_contribution_%', 'Goals_per_Match',
#        'Goals_Conceded_per_Game', 'Top_Scorer_Goals_per_Game', 'Win_%',
#        'Draw_%', 'Loss_%'],
#       dtype='object')

# %% [markdown]
# #### How have total points changed over the years?

# %%
rank_1 = All_season.loc[All_season['Rk'] == 1]
atleast_top_4 = All_season.loc[All_season['Rk'] == 4]
mid_table = All_season.loc[(All_season['Rk'] >= 7) & (All_season['Rk'] <= 13 )]
escape_relegation = All_season.loc[(All_season['Rk'] >= 14) & (All_season['Rk'] <=17 )]
relegated = All_season.loc[(All_season['Rk'] >= 18) & (All_season['Rk'] <=20 )]

# %%
rank_1.loc[:,'Pts_moving_avg'] = rank_1['Pts'].rolling(window=10).mean()
relegated.loc[:, 'Pts_moving_avg_'] = relegated['Pts'].rolling(window=10).mean()
atleast_top_4.loc[:, 'Pts_moving_avg_'] = atleast_top_4['Pts'].rolling(window=10).mean()
mid_table.loc[:, 'Pts_moving_avg_'] = mid_table['Pts'].rolling(window=10).mean()
escape_relegation.loc[:, 'Pts_moving_avg_'] = escape_relegation['Pts'].rolling(window=10).mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12712\3359180947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rank_1.loc[:,'Pts_moving_avg'] = rank_1['Pts'].rolling(window=10).mean()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12712\3359180947.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relegated.loc[:, 'Pts_moving_avg_'] = relegated['Pts'].rolling(window=10).mean()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12712\3359180947.py:3: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(15,7))
# Champion
sns.lineplot(data=rank_1,x='Season',y='Pts',c='g',marker="o",label= "League Winner")
sns.lineplot(data=rank_1,x='Season',y='Pts_moving_avg',c='indigo',linewidth=1,alpha=.7,label= "Trendlines") # Trendline
# Atlest top 4 or Champions league position.
sns.lineplot(data=atleast_top_4,x='Season',y='Pts',c='lawngreen',marker="o",ms = 6, mec = 'g',label= "Top 4 / Champions League Q")
sns.lineplot(data=atleast_top_4,x='Season',y='Pts_moving_avg_',c='indigo',linewidth=1,alpha=.7) # Trendline
# Mid- Table clubs
sns.lineplot(data=mid_table,x='Season',y='Pts',c='darkgoldenrod',marker="o",errorbar=None,ms = 6, mec = 'orange',label= "Mid-table")
sns.lineplot(data=mid_table,x='Season',y='Pts_moving_avg_',c='indigo',linewidth=1,alpha=.7,errorbar=None) # Trendline.
# # Escape_relegation
sns.lineplot(data=escape_relegation,x='Season',y='Pts',c='orange',marker="o",errorbar=None,label= "Relegation Survival")
sns.lineplot(data=escape_relegation,x='Season',y='Pts_moving_avg_',c='indigo',linewidth=1,alpha=.7,errorbar=None) # Trendline
# Relegated 
sns.lineplot(data=relegated,x='Season',y='Pts',c='r',marker="o",errorbar=None,label= "Relegation")
sns.lineplot(data=relegated,x='Season',y='Pts_moving_avg_',c='indigo',linewidth=1,alpha=.7,errorbar=None) # Trendline

plt.legend()
plt.grid()
x,y = plt.xticks(rotation=300)

# %% [markdown]
# #### Counts of Teams taking part

# %%
All_season.groupby(by="Season")['Squad'].count()
# Out:
# Season
# 1992-1993    22
# 1993-1994    22
# 1994-1995    22
# 1995-1996    20
# 1996-1997    20
# 1997-1998    20
# 1998-1999    20
# 1999-2000    20
# 2000-2001    20
# 2001-2002    20
# 2002-2003    20
# 2003-2004    20
# 2004-2005    20
# 2005-2006    20
# 2006-2007    20
# 2007-2008    20
# 2008-2009    20
# 2009-2010    20
# 2010-2011    20
# 2011-2012    20
# 2012-2013    20
# 2013-2014    20
# 2014-2015    20
# 2015-2016    20
# 2016-2017    20
# 2017-2018    20
# 2018-2019    20
# 2019-2020    20
# 2020-2021    20
# 2021-2022    20
# 2022-2023    20
# 2023-2024    20
# Name: Squad, dtype: int64

# %% [markdown]
# -----
#
# "The Premier League's structure shifted from 22 teams in its initial three seasons (1992-1995) to a consistent 20 teams from 1996 onward, a move intended to enhance quality, lessen player fatigue, and boost financial outcomes."

# %% [markdown]
# #### Which teams have been the most consistent?

# %%
print(All_season['Squad'].unique())
# Out:
# ['Manchester Utd' 'Aston Villa' 'Norwich City' 'Blackburn' 'QPR'
#  'Liverpool' 'Sheffield Weds' 'Tottenham' 'Manchester City' 'Arsenal'
#  'Chelsea' 'Wimbledon' 'Everton' 'Sheffield Utd' 'Coventry City'
#  'Ipswich Town' 'Leeds United' 'Southampton' 'Oldham Athletic'
#  'Crystal Palace' 'Middlesbrough' "Nott'ham Forest" 'Newcastle Utd'
#  'West Ham' 'Swindon Town' 'Leicester City' 'Bolton' 'Derby County'
#  'Sunderland' 'Barnsley' 'Charlton Ath' 'Bradford City' 'Watford' 'Fulham'
#  'Birmingham City' 'West Brom' 'Portsmouth' 'Wolves' 'Wigan Athletic'
#  'Reading' 'Stoke City' 'Hull City' 'Burnley' 'Blackpool' 'Swansea City'
#  'Cardiff City' 'Bournemouth' 'Brighton' 'Huddersfield' 'Brentford'
#  'Luton Town']

# %% [markdown]
# -----
# There are total 51 clubs which have participated in all Premier League seasons

# %%
All_season[All_season['Rk']== 1]['Squad'].value_counts()
# Out:
# Squad
# Manchester Utd     13
# Manchester City     8
# Chelsea             5
# Arsenal             3
# Blackburn           1
# Leicester City      1
# Liverpool           1
# Name: count, dtype: int64

# %% [markdown]
# --------------
# Manchester has been the epicenter of Premier League dominance, with two clubs significantly outperforming the rest. Manchester United leads the pack with an impressive 13 titles, followed by Manchester City with 8. Outside of Manchester, London's Chelsea has secured 5 championships, while Arsenal has claimed 3. Notably, Blackburn Rovers, Leicester City, and Liverpool each hold a single Premier League title.

# %%
def consistency(seasons,last_x_seasons,category):
    last_ = All_season['Season'].unique()
    # All seasons
    if category == 'Winner':
        up,lo = 1,1
    elif category == "Top 4":
        up,lo = 1,4
    elif category == "Mid-table":
        up,lo = 7,13
    elif category == "Relegation Survial":
        up,lo = 14,17
    elif category == "Relegation":
        up,lo = 18,20
        
    all_consist = pd.DataFrame(All_season.loc[(All_season['Rk'] >= up) & (All_season['Rk'] <= lo)]['Squad'].value_counts().reset_index())
    all_consist.columns = ['Squad','Overall performance']
    Last_seasons = All_season.loc[All_season['Season'] >= last_[len(last_) - last_x_seasons]]
    Last_consist = pd.DataFrame(Last_seasons.loc[(Last_seasons['Rk'] >= up) & (Last_seasons['Rk'] <= lo)]['Squad'].value_counts().reset_index())
    Last_consist.columns = ['Squad',f'Last {last_x_seasons} seasons performance - ({category})']
    tally = pd.DataFrame(all_consist.merge(Last_consist,how="left",on="Squad"))
    tally.fillna(0,inplace=True)
    tally.sort_values(f'Last {last_x_seasons} seasons performance - ({category})',inplace=True,ascending=False)
    return tally

# %%
consistency(seasons=All_season,last_x_seasons=5,category="Winner")
# Out:
#              Squad  Overall performance  Last 5 seasons performance - (Winner)
# 1  Manchester City                    8                                    4.0
# 6        Liverpool                    1                                    1.0
# 0   Manchester Utd                   13                                    0.0
# 2          Chelsea                    5                                    0.0
# 3          Arsenal                    3                                    0.0
# 4        Blackburn                    1                                    0.0
# 5   Leicester City                    1                                    0.0

# %% [markdown]
# - Manchester City has won 4 out of the last 5 titles, shows a clear recent dominance and now has 8 total titles
# - Liverpool - Only 1 overall title, but that came in the last 5 seasons. Despite fewer titles, team has been consistently in the top 2-3 teams recently.
# - Manchester United - Still holds the most overall titles (13) — showing historic dominance. However, no titles in the last 5 seasons, showing a clear fall from their peak
# - Chelsea has 5 titles but none recently, likely reflecting the post-Mourinho transition period.
# - Arsenal with 3 titles, also has no recent wins. Possibly rebounding now with Arteta, but titles are lacking.

# %%
consistency(seasons=All_season,last_x_seasons=5,category="Top 4")
# Out:
#               Squad  Overall performance  Last 5 seasons performance - (Top 4)
# 4   Manchester City                   14                                   5.0
# 2         Liverpool                   20                                   4.0
# 0    Manchester Utd                   26                                   3.0
# 3           Chelsea                   19                                   3.0
# 1           Arsenal                   23                                   2.0
# 5         Tottenham                    7                                   1.0
# 6     Newcastle Utd                    6                                   1.0
# 7       Aston Villa                    3                                   1.0
# 8         Blackburn                    3                                   0.0
# 9      Leeds United                    3                                   0.0
# 10     Norwich City                    1                                   0.0
# ...

# %%
consistency(seasons=All_season,last_x_seasons=5,category="Mid-table").head(10)
# Out:
#              Squad  Overall performance  \
# 16          Wolves                    5
# 1    Newcastle Utd                   15
# 10  Crystal Palace                    7
# 0         West Ham                   17
# 2          Everton                   14
# 3        Tottenham                   14
# 4           Fulham                   11
# 37       Brentford                    2
# 36        Brighton                    2
# 8      Aston Villa                    9
#
#     Last 5 seasons performance - (Mid-table)
# 16                                       4.0
# 1                                        4.0
# 10                                       3.0
# 0                                        2.0
# 2                                        2.0
# 3                                        2.0
# 4                                        2.0
# 37                                       2.0
# 36                                       2.0
# 8                                        2.0

# %%
consistency(seasons=All_season,last_x_seasons=5,category="Relegation Survial").head(10)
# Out:
#               Squad  Overall performance  \
# 0           Everton                   11
# 11   Crystal Palace                    4
# 2       Aston Villa                    8
# 3          West Ham                    7
# 26  Nott'ham Forest                    2
# 1       Southampton                    9
# 10         Brighton                    4
# 21     Leeds United                    3
# 18      Bournemouth                    3
# 16          Burnley                    3
#
#     Last 5 seasons performance - (Relegation Survial)
# 0                                                 3.0
# 11                                                2.0
# 2                                                 2.0
# 3                                                 2.0
# 26                                                2.0
# 1                                                 2.0
# 10                                                2.0
# 21                                                1.0
# ...

# %%
consistency(seasons=All_season,last_x_seasons=5,category="Relegation").head(10)
# Out:
#              Squad  Overall performance  \
# 0     Norwich City                    6
# 3          Watford                    4
# 4          Burnley                    4
# 6    Sheffield Utd                    4
# 12  Leicester City                    3
# 30     Bournemouth                    1
# 1        West Brom                    5
# 18    Leeds United                    2
# 41      Luton Town                    1
# 8           Fulham                    3
#
#     Last 5 seasons performance - (Relegation)
# 0                                         2.0
# 3                                         2.0
# 4                                         2.0
# 6                                         2.0
# 12                                        1.0
# 30                                        1.0
# 1                                         1.0
# 18                                        1.0
# 41                                        1.0
# 8                                         1.0

# %% [markdown]
# #### Have goals per season increased or decreased.

# %%
tab = pd.DataFrame(All_season.groupby(by="Season")['GF'].sum().round(1)).reset_index()

# %%
last_5_seasons = tab.tail().GF.mean()
tab['Goals_moving_avg'] = tab['GF'].rolling(window=8).mean()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=tab,x='Season',y='GF',marker="o")
sns.lineplot(data=tab,x='Season',y='Goals_moving_avg',alpha = 0.7,label="Trendline")
plt.legend(loc = 'upper center')
x,y =plt.xticks(rotation=300)
plt.grid()

# %%
plt.figure(figsize=(15,8))
dia = sns.barplot(data=tab,x="GF",y='Season',color='royalblue')
plt.axvline(x = 1043.8, color = 'r', linestyle = '--',label = "Last 5 seasons Average (Red line)") 
plt.axvline(x = 1032.9666666666667, color = 'b', linestyle = '--',label = "Average Goals includeing first 3 seasons (Blue line)")
plt.axvline(x = 1013.925925925926, color = 'g', linestyle = '--',label = "Average Goals excluding first 3 seasons (Green line)") 
plt.legend(bbox_to_anchor = (.1,.1), loc = 'lower left')
next_ = 0
for i in tab['GF']:
    dia.text(x=i/1.05,y=.2 + next_,s=str(i),color="white",fontsize=10)
    next_ = next_ + 1

# %% [markdown]
# --------------

# %% [markdown]
# 2006-2007 season saw least number of goals scored (931) and First season 1996-1997 season had most 1222 goals this is beause first three season of PL had 22 teams. In 20 teams PL season 2021-2022 season had most 1071 goals.

# %% [markdown]
# #### Has the league got competitive over time or not.

# %% [markdown]
# The competitiveness of a football league can be measured using several statistical and analytical methods
# 1. Points Distribution & Gap Between Teams. Standard Deviation, Points Difference Between 1st & 4th, 1st & 10th, or 1st & Lasttion of Points,
# 2. Title Race & Winner Variability (Number of Different Champions Over Time,How Early the League Title is Decided)
# 3. Champions League & Relegation Battle (Points Required for European Spots (Top 4, Top 6, etc.),Points Required to Avoid Relegation:)
# 4. Goal & Match Parity (Goal Difference Distribution, Number of Close Games (Decided by 1 Goal))

# %%
rank_1[['Squad','Season']]
plt.figure(figsize=(12,4))
sns.scatterplot(data=rank_1 ,x= 'Season',y='Squad',marker = "o",hue="Squad",s= 120)
plt.xlabel("Season")
plt.ylabel("Winning Club")
plt.title("Premier League Winners (1992-Present)")
plt.yticks(rotation=45)
plt.xticks(rotation=45)
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(14, 10))
axes[0].grid(True)

competitive = All_season.groupby(by='Season')['Pts'].std().reset_index()
competitive.columns = ['Seasons','_Points_Standard_deviation']
sns.lineplot(ax=axes[0],data=competitive,y='_Points_Standard_deviation',x='Seasons',c='orangered',marker = "o")
axes[0].set_xticks(range(len(competitive['Seasons'])))  # Set tick positions
axes[0].set_xticklabels(competitive['Seasons'], rotation=45)  # Set tick labels
axes[0].set_title('Points Standard Deviation Over Seasons')
axes[0].grid(True)


# Goal difference standard deviation
goal_diff = All_season.groupby(by='Season')['GD'].std().reset_index()
goal_diff.columns = ['Seasons', 'Goal_Diff_Standard_Deviation']
sns.lineplot(ax=axes[1], data=goal_diff, y='Goal_Diff_Standard_Deviation', x='Seasons',c='blue',marker = "o")
axes[1].set_xticks(range(len(goal_diff['Seasons'])))  # Set tick positions
axes[1].set_xticklabels(goal_diff['Seasons'], rotation=45)  # Set tick labels
axes[1].set_title('Goal Difference Standard Deviation Over Seasons')
axes[1].grid(True)


plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
# Set figure size
plt.figure(figsize=(14, 5))

# Filter top 2 ranked teams
top_2_comp = All_season.loc[All_season['Rk'] <= 2]
top_2_comp = top_2_comp.groupby(by='Season')['Pts'].std().reset_index()
top_2_comp.columns = ['Seasons', 'Points_Standard_deviation']

# Create line plot with markers and styling
sns.lineplot(data=top_2_comp, x='Seasons', y='Points_Standard_deviation', marker='o', linestyle='-', color='b')

plt.xticks(rotation=45, ha='right')  # Rotate for better readability
plt.xticks(range(len(top_2_comp['Seasons'])), top_2_comp['Seasons']) 

# Add grid, title, and labels
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlabel('Seasons', fontsize=12)
plt.ylabel('Standard Deviation of Points', fontsize=12)
plt.title('Standard Deviation of Points for Top 2 Ranked Teams Over Seasons', fontsize=14, fontweight='bold')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 7))

# Improved colormap and better color control
sns.lineplot(
    data=All_season, 
    x='Season', 
    y='Pts', 
    hue='Rk', 
    palette='plasma',  
    alpha=1,        # Transparency to reduce overlap clutter
    linewidth=1.5     # Thicker lines for clarity
)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.5)

# Add title and labels
plt.xlabel('Season', fontsize=12)
plt.ylabel('Points', fontsize=12)
plt.title('Competitiveness Over Seasons: Points vs Rank Trends', fontsize=14, fontweight='bold')

# Show legend outside the plot to avoid clutter
plt.legend(title="Rank (Rk)", bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust layout to avoid label overlap
plt.tight_layout()

plt.show()

# %% [markdown]
# Table Top and table bottom competition

# %%
plt.figure(figsize=(13,5))
table_top = All_season.loc[All_season['Rk']<= 10]
table_bottom = All_season.loc[All_season['Rk'] > 10]

table_top = table_top.groupby(by='Season')['Pts'].std().reset_index()
table_top.columns = ['Seasons','Standard_deviation']
sns.lineplot(data=table_top,y='Standard_deviation',x='Seasons')

table_bottom = table_bottom.groupby(by='Season')['Pts'].std().reset_index()
table_bottom.columns = ['Seasons','Standard_deviation']
table_bottom
sns.lineplot(data=table_bottom,y='Standard_deviation',x='Seasons')

x,y = plt.xticks(rotation=300)

# %% [markdown]
# ## Performance Analysis:
# - Which teams have the best points per match over all the seasons?
# - Are there patterns in how promoted teams perform in their first season?
# - Which teams rely the most on their top scorer for goals?

# %%
All_season.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'Attendance', 'Top Team Scorer', 'Goalkeeper', 'Notes', 'Season',
#        'Goals scored by top team scorer', 'years_in_PL_after_promotion',
#        'Promoted', 'Top_scorer_goal_contribution_%', 'Goals_per_Match',
#        'Goals_Conceded_per_Game', 'Top_Scorer_Goals_per_Game', 'Win_%',
#        'Draw_%', 'Loss_%'],
#       dtype='object')

# %%
All_season.groupby('Squad').agg(
    Seasons = ("Squad","count"),
    Average_points_per_match = ('Pts/MP','mean')
        ).reset_index().round(2).sort_values(by=['Seasons','Average_points_per_match'],ascending=False).head(20)
# Out:
#               Squad  Seasons  Average_points_per_match
# 28   Manchester Utd       32                      2.04
# 0           Arsenal       32                      1.89
# 25        Liverpool       32                      1.84
# 14          Chelsea       32                      1.83
# 44        Tottenham       32                      1.56
# 18          Everton       32                      1.35
# 30    Newcastle Utd       29                      1.39
# 1       Aston Villa       29                      1.33
# 47         West Ham       28                      1.26
# 27  Manchester City       27                      1.75
# 39      Southampton       24                      1.18
# 4         Blackburn       18                      1.39
# 24   Leicester City       17                      1.27
# 19           Fulham       17                      1.14
# 41       Sunderland       16                      1.02
# 23     Leeds United       15                      1.41
# ...

# %% [markdown]
# Are there patterns in how promoted teams perform in their first season?

# %%
teams_in_first_season_after_promotion = All_season.loc[(All_season['years_in_PL_after_promotion'] == 1) & (All_season['Season']>'1992-1993')]
teams_in_first_season_after_promotion_ = pd.DataFrame(teams_in_first_season_after_promotion['Notes'].value_counts()).reset_index().head(2)
sns.barplot(data= teams_in_first_season_after_promotion_,x='Notes',y='count',color='b')
plt.xlabel('Team Status', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of Teams stayed or relegated from PL after 1 year of Promotion', fontsize=10, fontweight='bold')

teams_in_first_season_after_promotion_
# Out:
#           Notes  count
# 0  Stayed_in_PL     46
# 1     Relegated     44

# %%
teams_in_first_season_after_promotion.groupby('Notes').agg(
    Count_teams_out_of_90 = ('Notes','count'),Average_Rank = ('Rk','mean'),
    Average_points = ('Pts','mean'),Average_Points_per_match = ('Pts/MP','mean'),
    Avg_goals_scored_by_teams_top_scorer = ('Goals scored by top team scorer','mean')
    ).reset_index().sort_values(by='Count_teams_out_of_90',ascending=False).head(2).round(2)
# Out:
#           Notes  Count_teams_out_of_90  Average_Rank  Average_points  \
# 2  Stayed_in_PL                     46         12.57           45.11
# 0     Relegated                     44         19.14           29.80
#
#    Average_Points_per_match  Avg_goals_scored_by_teams_top_scorer
# 2                      1.18                                 11.41
# 0                      0.78                                  9.05

# %%
All_season.groupby('Squad').agg(
    No_of_seasons = ('Squad',"count"),
    Average_Top_scorer_contribution_percentage = ('Top_scorer_goal_contribution_%','mean')
).reset_index().round(2).sort_values(by=['No_of_seasons','Average_Top_scorer_contribution_percentage'],ascending=False).head(15)
# Out:
#               Squad  No_of_seasons  Average_Top_scorer_contribution_percentage
# 44        Tottenham             32                                       27.85
# 0           Arsenal             32                                       27.78
# 25        Liverpool             32                                       25.88
# 28   Manchester Utd             32                                       25.08
# 18          Everton             32                                       24.11
# 14          Chelsea             32                                       22.11
# 30    Newcastle Utd             29                                       26.28
# 1       Aston Villa             29                                       25.47
# 47         West Ham             28                                       22.34
# 27  Manchester City             27                                       24.70
# 39      Southampton             24                                       27.79
# ...

# %%
All_season.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'Attendance', 'Top Team Scorer', 'Goalkeeper', 'Notes', 'Season',
#        'Goals scored by top team scorer', 'years_in_PL_after_promotion',
#        'Promoted', 'Top_scorer_goal_contribution_%', 'Goals_per_Match',
#        'Goals_Conceded_per_Game', 'Top_Scorer_Goals_per_Game', 'Win_%',
#        'Draw_%', 'Loss_%'],
#       dtype='object')

# %%
All_season.loc[(All_season['Promoted'] == 'Yes') & (All_season['Notes'].str.contains('Relegated'))].groupby('Squad').agg(
    Times_promoted = ('Promoted','count'),Times_Relegated = ('Notes','count')).reset_index()
# Out:
#               Squad  Times_promoted  Times_Relegated
# 0          Barnsley               1                1
# 1   Birmingham City               1                1
# 2         Blackpool               1                1
# 3            Bolton               2                2
# 4           Burnley               3                3
# 5      Cardiff City               2                2
# 6      Charlton Ath               1                1
# 7    Crystal Palace               3                3
# 8      Derby County               1                1
# 9            Fulham               2                2
# 10        Hull City               1                1
# 11     Leeds United               1                1
# 12   Leicester City               3                3
# 13       Luton Town               1                1
# 14  Manchester City               1                1
# 15    Middlesbrough               1                1
# 16     Norwich City               4                4
# ...

# %%
All_season[['Season','Squad','Notes','Promoted']].loc[All_season['Squad'] == 'Norwich City']
# Out:
#         Season         Squad                           Notes Promoted
# 2    1992-1993  Norwich City  → UEFA Cup via league finish 1      NaN
# 33   1993-1994  Norwich City                    Stayed_in_PL       No
# 63   1994-1995  Norwich City                       Relegated       No
# 264  2004-2005  Norwich City                       Relegated      Yes
# 397  2011-2012  Norwich City                    Stayed_in_PL      Yes
# 416  2012-2013  Norwich City                    Stayed_in_PL       No
# 443  2013-2014  Norwich City                       Relegated       No
# 484  2015-2016  Norwich City                       Relegated      Yes
# 565  2019-2020  Norwich City                       Relegated      Yes
# 605  2021-2022  Norwich City                       Relegated      Yes

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
#    - Do teams with higher average attendance perform better?
#    - Is there a strong relationship between goal difference and final league position?
#    - How important is having a top scorer with 20+ goals for league success?

# %% [markdown]
# Do teams with higher average attendance perform better?

# %%
sns.scatterplot(data=All_season,x="Pts",y='Attendance',hue = "Rk",palette="coolwarm")
# Out:
# <Axes: xlabel='Pts', ylabel='Attendance'>

# %% [markdown]
# Is there a strong relationship between goal difference and final league position?

# %%
# Compute correlation matrix
corr_matrix = All_season[['Rk','GD']].select_dtypes(include=['number']).corr()

# Create a heatmap
plt.figure(figsize=(5,5))
sns.heatmap(corr_matrix, 
            annot=True,       # Show correlation values
            fmt=".2f",        # Format decimal places
            cmap="coolwarm",  # Color map ('coolwarm', 'viridis', 'magma', etc.)
            linewidths=0.4,   # Line width between cells
            square=True,      # Makes the heatmap square
            cbar=True)        # Show color bar

# Add title
plt.title('Heatmap comparing (Position Vs Goal Difference) ', fontsize=8, fontweight='bold')

# Show plot
plt.show()

# %% [markdown]
# How important is having a top scorer with 20+ goals for the league success?

# %%
corr = All_season[['Rk', 'Goals scored by top team scorer']].corr()

# Create the subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# --- Scatter Plot on the Left ---
axes[0].scatter(All_season['Rk'], All_season['Goals scored by top team scorer'])
axes[0].set_xlabel("Rk")
axes[0].set_ylabel("Goals scored by top team scorer")
axes[0].set_title("Top Scorer Goals vs League Rank")

# --- Heatmap on the Right ---
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, ax=axes[1])
axes[1].set_title("Heatmap comparing (Position Vs Goals by Top Scorer)")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
rank_1.groupby('Rk')['Goals scored by top team scorer'].describe().round(2).reset_index()
# Out:
#    Rk  count   mean   std   min    25%   50%    75%   max
# 0   1   32.0  21.12  6.05  13.0  16.75  20.0  24.25  36.0

# %%
rank_1.loc[rank_1['Goals scored by top team scorer'] >= 20]['Season'].count()
# Out:
# 18

# %% [markdown]
# ## Attendance trends

# %%
Attendance_trends = pd.DataFrame(All_season.groupby(by="Season")['Attendance'].mean().round(1)).reset_index()

# %%
plt.figure(figsize=(15,10))
dia = sns.barplot(data=Attendance_trends,x="Attendance",y='Season',color='lime')
next_ = 0
for i in Attendance_trends['Attendance']:
    dia.text(x=i/1.2,y=.2 + next_,s=str(i),color="black",fontsize=10)
    next_ = next_ + 1

# %% [markdown]
# #### Over all trends of Attendance is going up from the start of PL.
# - In first 11 season of PL Average attendance grown form 21146 to 35466 which is 67% increase in Attendance.
# This may be because of teams have huge stadiums promoted to PL or teams in PL increased the capacity of stadium.
# - We see significant drop in attendance between 2019 - 2021, this is due to corona virus infaction that led to closed door matches.
# - 2021- 2022 season have all time highest Average Attendance

# %% [markdown]
# ## Know the Champions

# %%
rank_1 =  All_season.loc[All_season['Rk'] == 1]

# %%
rank_1['Squad'].value_counts()
# Out:
# Squad
# Manchester Utd     13
# Manchester City     8
# Chelsea             5
# Arsenal             3
# Blackburn           1
# Leicester City      1
# Liverpool           1
# Name: count, dtype: int64

# %% [markdown]
# ###### Only 7 Different teams had there hands on the trophy
# ###### Manchester United had won premier league trophy for most 13 times

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(data=rank_1,y="Season",x="Pts",color="gold")

plt.subplot(1,2,2)
rank_1['Pts'].plot(kind="kde",color='gold')
# Out:
# <Axes: ylabel='Density'>

# %%
rank_1['Pts'].mean(),rank_1['Pts'].median()
# Out:
# (87.78125, 89.0)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(data=rank_1,y='Season',x='Goals scored by top team scorer',color='r')
plt.subplot(1,2,2)
rank_1['Goals scored by top team scorer'].plot(kind="kde",color='r')
# Out:
# <Axes: ylabel='Density'>

# %%
rank_1['Goals scored by top team scorer'].mean(),rank_1['Goals scored by top team scorer'].median()
# Out:
# (21.125, 20.0)

# %% [markdown]
# #### From last 3 season top scorer of champion has scored less than average (20) this could because of there must be more than one player heavily contibuting to goals scored by team.

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(data=rank_1,y='Season',x='GF',color='magenta')
sns.barplot(data=rank_1,y="Season",x="Goals scored by top team scorer",color='lime')
plt.xlabel("Goals scored by top team scorer -- Vs -- Team Goals")
plt.subplot(1,2,2)
rank_1['GF'].plot(kind="kde",color='magenta')
# Out:
# <Axes: ylabel='Density'>

# %%
rank_1['GF'].mean(),rank_1['GF'].median()
# Out:
# (82.71875, 80.0)

# %%
rank_1['GF'].sum(),rank_1['Goals scored by top team scorer'].sum()
# Out:
# (2647, 676)

# %%
round((613/2457)*100,2)
# Out:
# 24.95

# %% [markdown]
# #### With little amount of data we have we got some insight about champions teams
# - To become champion of PL team atleast have to get 87 points.
# - Champion need a striker who can score atleast 20 in a season
# - Taking all seasons in perspective Top scorer of champion team atleast contribute 25% out of total goals scored by the team.

# %% [markdown]
# ## Know relegated teams

# %%
relegated_teams = All_season.loc[(All_season['Rk'] > 17) & (All_season['Rk'] <=20)]

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=relegated_teams,y='Squad',color='black')
# Out:
# <Axes: xlabel='count', ylabel='Squad'>

# %% [markdown]
# ##### Norwich City and West Brom are teams which relegated atleast 5 time in last 30 seasons

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(data=relegated_teams,y="Season",x="Pts",color="grey")

plt.subplot(1,2,2)
relegated_teams['Pts'].plot(kind="kde",color='grey')
# Out:
# <Axes: ylabel='Density'>

# %%
relegated_teams['Pts'].mean(),relegated_teams['Pts'].median()
# Out:
# (31.9375, 33.0)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(data=relegated_teams,y='Season',x='GF',color='plum')
sns.barplot(data=relegated_teams,y="Season",x="Goals scored by top team scorer",color='coral')
plt.xlabel("Goals scored by top team scorer -- Vs -- Team Goals")
plt.subplot(1,2,2)
relegated_teams['GF'].plot(kind="kde",color='blue')
# Out:
# <Axes: ylabel='Density'>

# %%
relegated_teams['Goals scored by top team scorer'].mean(),relegated_teams['Goals scored by top team scorer'].median()
# Out:
# (9.145833333333334, 8.5)

# %%
relegated_teams['GF'].sum(),relegated_teams['Goals scored by top team scorer'].sum()
# Out:
# (3563, 878)

# %%
round((820/3300)*100,1)
# Out:
# 24.8

# %% [markdown]
# - Teams should try to get more than 33 points to avoid relegation to lower division leagues
# - One thing that we also observed that in last 4 seasons the points gap between winner and relegated teams has increased. Teams are getting few points and getting relegated and on the other hand we see first 3 seasons we see teams with 40 to 50 points also got relegated.

# %%
relegated_teams['years_in_PL_after_promotion'].value_counts()
# Out:
# years_in_PL_after_promotion
# 1     46
# 2     14
# 3      5
# 6      5
# 4      4
# 7      4
# 8      4
# 10     3
# 11     3
# 13     2
# 5      2
# 9      1
# 12     1
# 16     1
# 24     1
# Name: count, dtype: int64

# %% [markdown]
# In last 30 seasons 90 teams relegated out which 40 relegated just after promotion, 14 relegated in there 2nd year in PL and 5 teams relegated in 3rd year of PL promotion.
# - For any promoted teams first 3 year are very risky and have chances of relegation.

# %% [markdown]
# ### Teams promoted but not relegated

# %%
promoted_teams_not_relegated = All_season.loc[(All_season['Promoted'] == "Yes") & (All_season['Notes'] != "Relegated")]

# %%
promoted_teams_not_relegated
# Out:
#      Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP  Attendance  \
# 24    3    Newcastle Utd  42  23   8  11  82  41  41   77    1.83       33792
# 34   13         West Ham  42  13  13  16  47  58 -11   52    1.24       20595
# 46    3  Nott'ham Forest  42  22  11   9  72  43  29   77    1.83       22079
# 77   12    Middlesbrough  38  11  10  17  35  50 -15   43    1.13       29220
# 94    9   Leicester City  38  12  11  15  46  54  -8   47    1.24       20183
# ..   ..              ...  ..  ..  ..  ..  ..  ..  ..  ...     ...         ...
# 618  13           Wolves  38  11   8  19  31  58 -27   41    1.08       31482
# 619  14         West Ham  38  11   7  20  42  55 -13   40    1.05       62462
# 620  15      Bournemouth  38  11   6  21  37  71 -34   39    1.03       10362
# 621  16  Nott'ham Forest  38   9  11  18  38  68 -30   38    1.00       29188
# 622  17          Everton  38   8  12  18  34  57 -23   36    0.95       39243
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=promoted_teams_not_relegated,y='Squad',color='blue')
# Out:
# <Axes: xlabel='count', ylabel='Squad'>

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(data=promoted_teams_not_relegated,y="Season",x="Pts",color="coral")

plt.subplot(1,2,2)
promoted_teams_not_relegated['Pts'].plot(kind="kde",color='coral')
# Out:
# <Axes: ylabel='Density'>

# %%
promoted_teams_not_relegated['Pts'].mean(),promoted_teams_not_relegated['Pts'].median()
# Out:
# (49.38461538461539, 46.0)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(data=promoted_teams_not_relegated,y='Season',x='GF',color='orange')
sns.barplot(data=promoted_teams_not_relegated,y="Season",x="Goals scored by top team scorer",color='deepskyblue')
plt.xlabel("Goals scored by top team scorer -- Vs -- Team Goals")
plt.subplot(1,2,2)
promoted_teams_not_relegated['GF'].plot(kind="kde",color='crimson')
# Out:
# <Axes: ylabel='Density'>

# %%
promoted_teams_not_relegated['Goals scored by top team scorer'].mean(),promoted_teams_not_relegated['Goals scored by top team scorer'].median()
# Out:
# (12.676923076923076, 11.0)

# %%
promoted_teams_not_relegated['GF'].sum(),promoted_teams_not_relegated['Goals scored by top team scorer'].sum()
# Out:
# (3125, 824)

# %%
round((577/2176)*100,1)
# Out:
# 26.5

# %%
plt.figure(figsize=(9,6))
sns.heatmap(All_season.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 2
#       1 plt.figure(figsize=(9,6))
# ----> 2 sns.heatmap(All_season.corr(),annot=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %% [markdown]
# # Competition among teams

# %% [markdown]
# Compitition means teams are fighting for each single points, we all like compitition where anybody has power to beat anybody and matches are not predictable.

# %% [markdown]
# If we try to understand compitition in a league we can get a signal from points each team gets and what is the difference of points between teams

# %% [markdown]
# For example - We see the points gap between 1st and 2nd finishing teams in season 2004-2005 and 2011-2012, we find the gap between 2004-2005 season is large to season 2011-2012

# %% [markdown]
# In 2011-2012 season there is no points difference in 1st and 2nd finishing team and it was a very close fight and in this same season Sergio Aguero scored the last minute goal against QPR in a title deciding match. (Agueroooooooooooooooo)

# %% [markdown]
# If we ask anybody they will tell us 2011-2012 season was more interesting than 2004-2005 because the title battle was very close. Same goes for relegation battle and each rank teams fight for

# %% [markdown]
# For better understanding see visual down below.

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=All_season,x="Season",y="Pts",hue='Rk')
plt.xticks(rotation=90)

# %% [markdown]
# To understand which part of seasons table is more compititive in terms of points gap

# %%
top_5_teams = All_season.loc[All_season['Rk'] <= 5]
teams_rank_6_to_10 = All_season.loc[(All_season['Rk'] > 5) & (All_season['Rk'] <=10 )]
teams_rank_11_to_15 = All_season.loc[(All_season['Rk'] > 10) & (All_season['Rk'] <=15 )]
teams_rank_16_to_20 = All_season.loc[(All_season['Rk'] > 15) & (All_season['Rk'] <=20 )]

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=top_5_teams,x="Season",y="Pts",color= "r")
sns.lineplot(data=teams_rank_6_to_10,x="Season",y="Pts",color ='blue')
sns.lineplot(data=teams_rank_11_to_15,x="Season",y="Pts",color = "green")
sns.lineplot(data=teams_rank_16_to_20,x="Season",y='Pts',color='m')
x,y =plt.xticks(rotation=300)

# %% [markdown]
# Red part shows top 5 teams, Blue part shows teams ranking 6 to 10,Green part shows teams ranking 11 to 15 and megenta part show teams raning from 16 to 20

# %% [markdown]
# We observed that green part is very thiner, that shows the points difference between teams (11-15) is less as compared to teams in red part

# %% [markdown]
# It is very hard to sustain and maintain a single rank / position in green part of season table because if a teams does not get points after a match other teams will overtake as points difference is very less.

# %% [markdown]
# So teams ranking from 11 to 15 are very compititive.
