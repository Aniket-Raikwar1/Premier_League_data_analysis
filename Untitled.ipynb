# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Datasets/Players_data/2022-2023/Player_stats_standard-2022-2023')

# %%
df
# Out:
#         Rk            Player   Nation    Pos           Squad  \
# 0        1  Brenden Aaronson   us USA  MF,FW    Leeds United
# 1        2   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt
# 2        3    James Abankwah   ie IRL     DF         Udinese
# 3        4     George Abbott  eng ENG     MF       Tottenham
# 4        5  Yunis Abdelhamid   ma MAR     DF           Reims
# ...    ...               ...      ...    ...             ...
# 2884  2885  Szymon Żurkowski   pl POL     MF      Fiorentina
# 2885  2886  Szymon Żurkowski   pl POL     MF          Spezia
# 2886  2887   Martin Ødegaard   no NOR     MF         Arsenal
# 2887  2888       Milan Đurić   ba BIH     FW   Hellas Verona
# 2888  2889     Filip Đuričić   rs SRB  MF,FW       Sampdoria
#
#                     Comp  Age  Born  Playing Time MP  Playing Time Starts  \
# 0     eng Premier League   21  2000               36                   28
# 1          de Bundesliga   18  2003                7                    0
# ...

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born',
#        'Playing Time MP', 'Playing Time Starts', 'Playing Time Min',
#        'Playing Time 90s', 'Performance Gls', 'Performance Ast',
#        'Performance G+A', 'Performance G-PK', 'Performance PK',
#        'Performance PKatt', 'Performance CrdY', 'Performance CrdR',
#        'Expected xG', 'Expected npxG', 'Expected xAG', 'Expected npxG+xAG',
#        'Progression PrgC', 'Progression PrgP', 'Progression PrgR',
#        'Per 90 Minutes Gls', 'Per 90 Minutes Ast', 'Per 90 Minutes G+A',
#        'Per 90 Minutes G-PK', 'Per 90 Minutes G+A-PK', 'Per 90 Minutes xG',
#        'Per 90 Minutes xAG', 'Per 90 Minutes xG+xAG', 'Per 90 Minutes npxG',
#        'Per 90 Minutes npxG+xAG', 'Matches'],
#       dtype='object')

# %%
new_col =  ['Rank', 'Player', 'Nation', 'Position', 'Squad', 'League', 'Age', 'Born',
       'Matches Played', 'Starts', 'Minutes',
       '90s Played', 'Goals', 'Assists',
       'Performance Goals+Assist', 'Non-Panelty_Goals', 'Panelty_Goals',
       'Panelty_Kick_attempts', 'Yellow_Cards', 'Red_Cards',
       'Expected_Goals_xG', 'Non_Panelty_Expected_goals_npxG', 'Expected_Assisted_Goals_xAG', 'Expected_npxG+xAG',
       'Progressive_carries_PrgC', 'Progressive_Passes_PrgP', 'Progressive__Passes_Received_PrgR',
       'Per_90_Minutes_Goals', 'Per_90_Minutes_Assists', 'Per_90_Minutes_Goals+Assists',
       'Per_90_Minutes_Non-Panelty_Goals', 'Per 90 Minutes G+A-PK', 'Per 90 Minutes xG',
       'Per_90_Minutes_Expected_Assisted_Goals_xAG', 'Per_90_Minutes_xG+xAG', 'Per_90_Minutes_npxG',
       'Per_90_Minutes_npxG+xAG', 'Matches']
df.columns = new_col

# %%
df.sort_values(['Player'])
# Out:
#       Rank             Player Nation Position            Squad  \
# 609    610    Aaron Cresswell    ENG       DF         West Ham
# 1194  1195       Aaron Hickey    SCO       DF        Brentford
# 2194  2195     Aaron Ramsdale    ENG       GK          Arsenal
# 2195  2196       Aaron Ramsey    WAL       MF             Nice
# 2775  2776  Aaron Wan-Bissaka    ENG       DF   Manchester Utd
# ...    ...                ...    ...      ...              ...
# 1118  1119     İlkay Gündoğan    GER       MF  Manchester City
# 867    868   Łukasz Fabiański    POL       GK         West Ham
# 2147  2148      Łukasz Poręba    POL       MF             Lens
# 2470  2471   Łukasz Skorupski    POL       GK          Bologna
# 2183  2184        Ștefan Radu    ROU       FW            Lazio
#
#                   League  Age  Born  Matches Played  Starts  ...  \
# 609   eng Premier League   32  1989              28      24  ...
# 1194  eng Premier League   20  2002              26      23  ...
# ...
